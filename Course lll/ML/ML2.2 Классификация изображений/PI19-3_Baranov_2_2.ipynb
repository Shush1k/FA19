# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

plt.rcParams["figure.figsize"] = (8, 8)

# %%
df = datasets.fetch_olivetti_faces(data_home='data')
print(df.DESCR)

# %%
n = 3
fig, axs = plt.subplots(n, n)
for i in range(n):
    for j in range(n):
        axs[i][j].imshow(df['images'][i*n + j], cmap=plt.cm.bone)

# %%
df.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])

# %%
x, y = df['data'], df['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=True)

# %%
svc = SVC()
svc.fit(x_train, y_train)
y_test_predict = svc.predict(x_test)

# %%
print(metrics.classification_report(y_test, y_test_predict, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       1.00      1.00      1.00         4
#            2       0.50      1.00      0.67         3
#            3       0.00      1.00      0.00         0
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       0.67      1.00      0.80         4
#            7       1.00      0.50      0.67         2
#            8       0.67      0.80      0.73         5
#            9       1.00      0.50      0.67         6
#           10       1.00      1.00      1.00         3
#           11       0.67      1.00      0.80         2
#           12       1.00      0.67      0.80         3
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         1
#           15       0.50      1.00      0.67         1
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         5
#           18       1.00      1.00      1.00         3
#           19       1.00      1.00      1.00         1
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         3
#           22       1.00      0.00      0.00         6
#           23       1.00      1.00      1.00         2
#           24       0.80      1.00      0.89         4
#           25       0.67      1.00      0.80         2
#           26       1.00      1.00      1.00         2
#           27       1.00      0.80      0.89         5
#           28       1.00      1.00      1.00         4
#           29       0.80      1.00      0.89         4
#           30       1.00      1.00      1.00         2
#           31       1.00      1.00      1.00         4
#           32       1.00      1.00      1.00         4
#           33       1.00      1.00      1.00         2
#           34       1.00      1.00      1.00         2
#           35       1.00      0.33      0.50         3
#           36       1.00      1.00      1.00         4
#           37       1.00      1.00      1.00         3
#           38       1.00      1.00      1.00         5
#           39       0.67      0.50      0.57         4
#
#     accuracy                           0.85       120
#    macro avg       0.89      0.89      0.85       120
# weighted avg       0.91      0.85      0.84       120

# %%
# дальше не понятно
