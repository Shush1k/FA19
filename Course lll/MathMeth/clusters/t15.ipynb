# %% [markdown]
# ## Задача 1 (15:40) - Метод ветвей и границ
#
# $$ z = x_1+x_2 =>max $$
# $$\begin{cases}
# 2x_1+x_2<=6\\
# 2x_1+4x_2<=10
# \end{cases}$$
#
# $X^{*}=(2\frac{1}{3},\frac{4}{3},0,0)$
#
# Берем ближайшие целые числа для $x_1$ -> $2\frac{1}{3}$ - это 2 и 3
#
# Берем ближайшие целые числа для $x_2$ -> $\frac{4}{3}$ - это 1 и 2
#
# 1. $x_1=2$
# $$
# max(2+x_2)
# $$
# $$\begin{cases}
# 4+x_2<=6\\
# 4+4x_2<=10\\
# x_2>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_2<=2\\
# x_2<=\frac{3}{2}\\
# \end{cases}$$
#
# Получается, что $x_2=1; z = 2 + 1 = 3$
#
# 2. $x_1 = 3$
#
# $$max(3+x_2)$$
#
# $$\begin{cases}
# 6+x_2<=6\\
# 6+4x_2<=10\\
# x_2>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_2<=0\\
# x_2<=1\\
# x_2>=0
# \end{cases}$$
#
# Получается, что $x_2=0; z = 3 + 0 = 3$
#
# 3. $x_2=1$
#
# $$max(x_1+1)$$
#
# $$\begin{cases}
# 2x_1+1<=6\\
# 2x_1+4<=10\\
# x_1>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_1<=\frac{5}{2}\\
# x_1<=3\\
# x_1>=0
# \end{cases}$$
#
# Получается, что $x_1=2; z = 2 + 1 = 3$
#
# 4. $x_2=2$
#
# $$max(x_1+2)$$
#
# $$\begin{cases}
# 2x_1+2<=6\\
# 2x_1+8<=10\\
# x_1>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_1<=2\\
# x_1<=1\\
# x_1>=0
# \end{cases}$$
#
# Получается, что $x_1=1; z = 1 + 2 = 3$
#
# Ответ (_не очень понятно какой ответ_): $$X^{*}=(2,1);z=3$$

# %% [markdown]
# ## Задача 2 (16:05) - Метод ветвей и границ
# $$x_1+5x_2 \rightarrow max$$
#
# $$\begin{cases}
# -x_1+x_2<=2\\
# x_1+x_2<=7\\
# x_{1,2}>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_2<=x_1+2\\
# x_2<=7-x_1
# \end{cases}$$
#
# <div style="text-align:center">
#   <img src="t15/t2.png" width="500"/>
# </div>

# %% [markdown]
# $$x_1=\frac{5}{2};x_2=\frac{9}{2}$$
#
# Берем ближайшие целые числа для $\frac{5}{2}$ - это 2 и 3
#
# Берем ближайшие целые числа для $\frac{9}{2}$ - это 4 и 5
#
# 1. $x_1=2$
#
# $$z = 2+5x_2 \rightarrow max$$
#
# $$\begin{cases}
# -2+x_2<=2\\
# 2+x_2<=7\\
# x_2>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_2<=4\\
# x_2<=5\\
# x_2>=0
# \end{cases}$$
#
# Получается, что $x_2=4; z = 2 + 5*4 = 22$
#
# 2. $x_1=3$
#
# $$z = 3+5x_2 \rightarrow max$$
#
# $$\begin{cases}
# -3+x_2<=2\\
# 3+x_2<=7\\
# x_2>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_2<=5\\
# x_2<=4\\
# x_2>=0
# \end{cases}$$
#
# Получается, что $x_2=4; z = 3 + 5*4 = 23$
#
# 3. $x_2=4$
#
# $$z = x_1+20 \rightarrow max$$
#
# $$\begin{cases}
# -x_1+4<=2\\
# x_1+4<=7\\
# x_1>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_1>=2\\
# x_1<=3\\
# x_1>=0
# \end{cases}$$
#
# Получается, что $x_1=3; z = 3 + 5*4 = 23$
#
# 4. $x_2=5$
#
# $$z = x_1+20 \rightarrow max$$
#
# $$\begin{cases}
# -x_1+5<=2\\
# x_1+5<=7\\
# x_1>=0
# \end{cases}$$
#
# $$\begin{cases}
# x_1>=3\\
# x_1<=2\\
# x_1>=0
# \end{cases}$$
#
# $$\varnothing$$
#
# отсекаем z = 22, т.к она не максимальна => рассматриваем z = 23
#
# Ответ: $$X^{*}=(3,4);z=23$$

# %% [markdown]
# ## Задача 3 (16:20) - Транспортная задача
#
# | $c_{i,j}$ | $b_1$ | $b_2$ | $b_3$ | $b_4$ |     |
# |-----------|-------|-------|-------|-------|-----|
# | $a_1$     | 8     | 6     | 9     | 2     | 160 |
# | $a_2$     | 7     | 16    | 12    | 12    | 60  |
# | $a_3$     | 6     | 15    | 8     | 3     | 180 |
# |           | 80    | 60    | 60    | 200   | 400 |
#
# $$\sum_{i=0}^3 a_{i} = \sum_{j=0}^4 b_{j}$$
#
# n+m-1 = 4 + 3 -1 = 6
#
# $$u_i + v_j = c_{i,j}$$
#
# Для свободных клеток
#
#
# $$u_i + v_j <= c_{i,j}$$
# $$u_i + v_j - c_{i,j} <= 0$$
#
# 1. 6 + 3 - 2 = 7
# 2. 9 + 2 - 7 = 4
# 3. 9 + 0 - 16 = -7
# 4. 0 + 2 - 6 = -4
# 5. 0 + 0 - 15 = -15
# 6. 0 + 3 - 8 = -5
#
# если получось > 0 => план не оптимален
#
# $max(7;4)=7$

# %% [markdown]
# ## ДЗ
# стр 94 №14 - Метод ветвей и границ
#
# стр 116 №3 - Транспортная

# %% [markdown]
# ### 14-ая задача - Метод ветвей и границ
# <div style="text-align:center">
#   <img src="t15/t14.png" width="500"/>
# </div>

# %% [markdown]
# $$z=3x_1+5x_2+1 \rightarrow max$$
#
# $$\begin{cases}
# -x_1+x_2 \leq 3\\
# x_1+x_2 \leq 12\\
# x_{1,2} \geq 0\\
# x_{1,2} \in Z
# \end{cases}$$
#
# $$\begin{cases}
# -x_1+x_2+x_3 = 3\\
# x_1+x_2+x_4 = 12
# \end{cases}$$
#
# | Б     | С  | $x_1$ | $x_2$   | $x_3$ | $x_4$ |
# |-------|----|-------|---------|-------|-------|
# | $x_3$ | 3  | -1    | <u>1<u> | 1     | 0     |
# | $x_4$ | 12 | 1     | 1       | 0     | 1     |
# | z     | 0  | -3    | -5      | 0     | 0     |
#
# $min(3:1;12:1)=3$
#
# | Б     | С  | $x_1$   | $x_2$ | $x_3$ | $x_4$ |
# |-------|----|---------|-------|-------|-------|
# | $x_2$ | 3  | -1      | 1     | 1     | 0     |
# | $x_4$ | 9  | <u>2<u> | 0     | -1    | 1     |
# | z     | 15 | -8      | 0     | 5     | 0     |
#
# $min(-;9:2)=4.5$
#
# | Б     | С              | $x_1$ | $x_2$ | $x_3$          | $x_4$         |
# |-------|----------------|-------|-------|----------------|---------------|
# | $x_2$ | $\frac{15}{2}$ | 0     | 1     | $\frac{1}{2}$  | $\frac{1}{2}$ |
# | $x_1$ | $\frac{9}{2}$  | 1     | 0     | -$\frac{1}{2}$ | $\frac{1}{2}$ |
# | z     | 51             | 0     | 0     | 1              | 4             |
#
# $X^{*}=(\frac{9}{2}, \frac{15}{2}, 0, 0)$
#
# $z=3*\frac{9}{2}+5*\frac{15}{2}+1 = 52$
#
# ---
#
# $$\begin{cases}
# x_2 \leq 3+x_1\\
# x_2 \leq 12-x_1\\
# \end{cases}$$
#
#
# $$\begin{cases}
# x_1 =\frac{9}{2}\\
# x_2 =\frac{15}{2}\\
# \end{cases}$$
#
# Берем ближайшие целые числа для $\frac{9}{2}$ - это 4 и 5
#
# Берем ближайшие целые числа для $\frac{15}{2}$ - это 7 и 8
#
# 1. $x_1=4$
#
# $$z=5x_2+13 \rightarrow max$$
#
# $$\begin{cases}
# -4+x_2 \leq 3\\
# 4+x_2 \leq 12\\
# x_2 \geq 0
# \end{cases}$$
#
# $$\begin{cases}
# x_2 \leq 7\\
# x_2 \leq 8\\
# x_2 \geq 0
# \end{cases}$$
#
# Получается, что $x_2=7; z = 5*7+13 = 48$
#
# 2. $x_1=5$
#
# $$z=5x_2+16 \rightarrow max$$
# $$\begin{cases}
# -5+x_2 \leq 3\\
# 5+x_2 \leq 12
# x_2 \geq 0
# \end{cases}$$
#
# $$\begin{cases}
# x_2 \leq 8\\
# x_2 \leq 7\\
# x_2 \geq 0
# \end{cases}$$
#
# Получается, что $x_2=7; z = 5*7+16=51$
#
# 3. $x_2=7$
#
# $$z=3x_1+36 \rightarrow max$$
#
# $$\begin{cases}
# -x_1+7 \leq 3\\
# x_1+7 \leq 12\\
# x_2 \geq 0
# \end{cases}$$
#
# $$\begin{cases}
# x_1 \geq 4\\
# x_1 \leq 5\\
# x_2 \geq 0
# \end{cases}$$
#
# Получается, что $x_1=5; z = 3*5+36=51$
#
# 4. $x_2=8$
#
# $$z=3x_1+41 \rightarrow max$$
#
# $$\begin{cases}
# -x_1+8 \leq 3\\
# x_1+8 \leq 12\\
# x_2 \geq 0
# \end{cases}$$
#
# $$\begin{cases}
# x_1 \geq 5\\
# x_1 \leq 4\\
# x_2 \geq 0
# \end{cases}$$
#
# $$\varnothing$$
#
# Максимум функции: z = 51
#
# Ответ: $$X^{*}=(5,7);z=51$$

# %% [markdown]
# ### 3-яя задача - Транспортная
# <div style="text-align:center">
#   <img src="t15/t3.png" width="500"/>
# </div>

# %% [markdown]
# $\sum a = 80 + 40 + 90 + 80 = 290$
#
# $\sum b = 90 + 60 + 140 = 290$
#
# $\sum a = \sum b$
#
# | $c_{i,j}$ | $b_1$  | $b_2$  | $b_3$  | $b_4$  |     |
# |-----------|--------|--------|--------|--------|-----|
# | $a_1$     | 10[80] | 10[10] | 4      | 8      | 90  |
# | $a_2$     | 14     | 25[30] | 13[30] | 23     | 60  |
# | $a_3$     | 12     | 13     | 6[60]  | 12[80] | 140 |
# |           | 80     | 40     | 90     | 80     |     |
#
# находим потенциалы
#
# | $c_{i,j}$ | $v_1=10$ | $v_2=10$ | $v_3=-2$ | $v_4=4$ |
# |-----------|----------|----------|----------|---------|
# | $u_1=0$   | 10[80]   | 10[10]   | 4        | 8       |
# | $u_2=15$  | 14       | 25[30]   | 13[30]   | 23      |
# | $u_3=8$   | 12       | 13       | 6[60]    | 12[80]  |
#
# Опорный план не оптимален, т.к. есть $u_i + v_j > c_{i,j}$
#
# $u_2+v_1 > c_{2,1}; 15+10> 14; 11>0$
#
# $u_3+v_1 > c_{3,1}; 8+10> 12; 6>0$
#
# $u_3+v_2 > c_{3,2}; 8+10> 13; 5>0$
#
# $max(11,6,5)=11$
#
# Выбираем $u_2,v_1 = 14$
#
# | $c_{i,j}$ | $b_1$     | $b_2$     | $b_3$  | $b_4$  |     |
# |-----------|-----------|-----------|--------|--------|-----|
# | $a_1$     | 10[80][-] | 10[10][+] | 4      | 8      | 90  |
# | $a_2$     | 14[+]     | 25[30][-] | 13[30] | 23     | 60  |
# | $a_3$     | 12        | 13        | 6[60]  | 12[80] | 140 |
# |           | 80        | 40        | 90     | 80     |     |
#
# Там где [-] => $min(80;30) =30$
#
# | $c_{i,j}$ | $b_1$  | $b_2$  | $b_3$  | $b_4$  |     |
# |-----------|--------|--------|--------|--------|-----|
# | $a_1$     | 10[50] | 10[40] | 4      | 8      | 90  |
# | $a_2$     | 14[30] | 25     | 13[30] | 23     | 60  |
# | $a_3$     | 12     | 13     | 6[60]  | 12[80] | 140 |
# |           | 80     | 40     | 90     | 80     |     |
#
# Новый опорный план; находим потенциалы
#
# | $c_{i,j}$ | $v_1=10$ | $v_2=10$ | $v_3=9$ | $v_4=15$ |
# |-----------|----------|----------|---------|----------|
# | $u_1=0$   | 10[50]   | 10[40]   | 4       | 8        |
# | $u_2=4$   | 14[30]   | 25       | 13[30]  | 23       |
# | $u_3=-3$  | 12       | 13       | 6[60]   | 12[80]   |
#
# Опорный план не оптимален, т.к. есть $u_i + v_j > c_{i,j}$
#
# для строк (1;3), (1;4)
#
# $u_1+v_3 > c_{1,3}; 0+9>4; 5>0$
#
# $u_1+v_4 > c_{1,4}; 0+15>8; 7>0$
#
# $max(5, 7)=7$
#
# Выбираем $u_1,v_4 = 8$
#
# | $c_{i,j}$ | $b_1$     | $b_2$  | $b_3$     | $b_4$     |     |
# |-----------|-----------|--------|-----------|-----------|-----|
# | $a_1$     | 10[50][-] | 10[40] | 4         | 8[+]      | 90  |
# | $a_2$     | 14[30][+] | 25     | 13[30][-] | 23        | 60  |
# | $a_3$     | 12        | 13     | 6[60][+]  | 12[80][-] | 140 |
# |           | 80        | 40     | 90        | 80        |     |
#
# Там где [-] => $min(80;50;30) =30$
#
# | $c_{i,j}$ | $b_1$  | $b_2$  | $b_3$ | $b_4$  |     |
# |-----------|--------|--------|-------|--------|-----|
# | $a_1$     | 10[20] | 10[40] | 4     | 8[30]  | 90  |
# | $a_2$     | 14[60] | 25     | 13    | 23     | 60  |
# | $a_3$     | 12     | 13     | 6[90] | 12[50] | 140 |
# |           | 80     | 40     | 90    | 80     |     |
#
# Новый опорный план; находим потенциалы
#
# | $c_{i,j}$ | $v_1=10$ | $v_2=10$ | $v_3=2$ | $v_4=8$ |
# |-----------|----------|----------|---------|---------|
# | $u_1=0$   | 10[20]   | 10[40]   | 4       | 8[30]   |
# | $u_2=4$   | 14[60]   | 25       | 13      | 23      |
# | $u_3=4$   | 12       | 13       | 6[90]   | 12[50]  |
#
# Опорный план не оптимален, т.к. есть $u_i + v_j > c_{i,j}$
#
# для строк (3;1), (3;2)
#
# $u_3+v_1 > c_{3,1}; 4+10>12; 2>0$
#
# $u_3+v_2 > c_{3,2}; 4+10>13; 1>0$
#
# $max(2, 1)=2$
#
# Выбираем $u_3,v_1 = 2$
#
# | $c_{i,j}$ | $b_1$     | $b_2$  | $b_3$ | $b_4$     |     |
# |-----------|-----------|--------|-------|-----------|-----|
# | $a_1$     | 10[20][-] | 10[40] | 4     | 8[30][+]  | 90  |
# | $a_2$     | 14[60]    | 25     | 13    | 23        | 60  |
# | $a_3$     | 12[+]     | 13     | 6[90] | 12[50][-] | 140 |
# |           | 80        | 40     | 90    | 80        |     |
#
# Там где [-] => $min(20;50) =20$
#
# | $c_{i,j}$ | $b_1$  | $b_2$  | $b_3$ | $b_4$  |     |
# |-----------|--------|--------|-------|--------|-----|
# | $a_1$     | 10     | 10[40] | 4     | 8[50]  | 90  |
# | $a_2$     | 14[60] | 25     | 13    | 23     | 60  |
# | $a_3$     | 12[20] | 13     | 6[90] | 12[30] | 140 |
# |           | 80     | 40     | 90    | 80     |     |
#
# Новый опорный план; находим потенциалы
#
# | $c_{i,j}$ | $v_1=8$ | $v_2=10$ | $v_3=2$ | $v_4=8$ |
# |-----------|---------|----------|---------|---------|
# | $u_1=0$   | 10      | 10[40]   | 4       | 8[50]   |
# | $u_2=6$   | 14[60]  | 25       | 13      | 23      |
# | $u_3=4$   | 12[20]  | 13       | 6[90]   | 12[30]  |
#
# Опорный план не оптимален, т.к. есть $u_i + v_j > c_{i,j}$
#
# для строк (3;2)
#
# $u_3+v_2 > c_{3,2}; 4+10>13; 1>0$
#
# $max(1)=1$
#
# Выбираем $u_3,v_2 = 1$
#
# | $c_{i,j}$ | $b_1$  | $b_2$     | $b_3$ | $b_4$     |     |
# |-----------|--------|-----------|-------|-----------|-----|
# | $a_1$     | 10     | 10[40][-] | 4     | 8[50][+]  | 90  |
# | $a_2$     | 14[60] | 25        | 13    | 23        | 60  |
# | $a_3$     | 12[20] | 13[+]     | 6[90] | 12[30][-] | 140 |
# |           | 80     | 40        | 90    | 80        |     |
#
# Там где [-] => $min(40;30) =30$
#
# | $c_{i,j}$ | $b_1$  | $b_2$  | $b_3$ | $b_4$ |     |
# |-----------|--------|--------|-------|-------|-----|
# | $a_1$     | 10     | 10[10] | 4     | 8[80] | 90  |
# | $a_2$     | 14[60] | 25     | 13    | 23    | 60  |
# | $a_3$     | 12[20] | 13[30] | 6[90] | 12    | 140 |
# |           | 80     | 40     | 90    | 80    |     |
#
# Новый опорный план; находим потенциалы
# | $c_{i,j}$ | $v_1=9$ | $v_2=10$ | $v_3=3$ | $v_4=8$ |
# |-----------|---------|----------|---------|---------|
# | $u_1=0$   | 10      | 10[10]   | 4       | 8[80]   |
# | $u_2=5$   | 14[60]  | 25       | 13      | 23      |
# | $u_3=3$   | 12[20]  | 13[30]   | 6[90]   | 12      |
#
# Опорный план оптимален, т.к. все условия соблюдены для  $u_i + v_j \leq c_{i,j}$
#
# $F = 10*10+8*80+14*60+12*20+13*30+6*90=2750$

# %% [markdown]
# КР 26.04
#
# 1. теория двойственности
# 2. целочисленное (симплекс метод + метод ветвей и границ)
# 3. транспортная
